# %%
#Import necessary libraries
import pandas as pd
import matplotlib as plt
import seaborn as sns
import numpy as np

# %%
#view the data
power_ran = pd.read_csv("data/power_rangers_episodes.csv")

power_ran
# Out:
#                   season_title  episode_num          episode_title  \
# 0    Mighty Morphin (Season 1)            0       The Lost Episode
# 1    Mighty Morphin (Season 1)            1    Day of the Dumpster
# 2    Mighty Morphin (Season 1)            2              High Five
# 3    Mighty Morphin (Season 1)            3               Teamwork
# 4    Mighty Morphin (Season 1)            4  A Pressing Engagement
# ..                         ...          ...                    ...
# 916  Beast Morphers (Season 2)           18            Crunch Time
# 917  Beast Morphers (Season 2)           19            Source Code
# 918  Beast Morphers (Season 2)           20         Evox Unleashed
# 919  Beast Morphers (Season 2)           21               Boxed In
# 920  Beast Morphers (Season 2)           22             Making Bad
#
#        air_date  IMDB_rating  total_votes  \
# 0    1999-05-22          6.7          113
# 1    1993-08-28          7.4          687
# ...

# %%
#create line graph for rough visualization
sns.lineplot(data = power_ran, x="air_date", y = "IMDB_rating")
# Out:
# c:\Users\patty\anaconda3\envs\eds217_2023\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\patty\anaconda3\envs\eds217_2023\lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='air_date', ylabel='IMDB_rating'>

# %%
#thinking to see the years? or how about months overall? i think if i do months, I would have to think if I want to do mean, add all of them up, max, min etc)
#or if i do months overall, I would look at one year. I can compare years as well. Maybe compare a certain month with a couple of years

# %%
#data wrangle to show only years
